# %% [markdown]
# In this file, I will download pictures from pinterest.com
#
# ## 1. Download boards information
#
#     1. load pinterest.com
#     2. search keyword "face" in all board
#     3. parse username/boardname
#     4. get pictures

# %%
import os
cdir = os.path.abspath(os.path.dirname("__file__"))

import sys
sys.path.insert(0, cdir + "/..")

# %%
from modules.parse_boards import *
import cPickle as pickle
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import time

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
bucket_pins=set()
browser = webdriver.Chrome()

browser.get("https://www.pinterest.com/search/boards/?q=face")
browser.find_element_by_class_name("buttonText").click()

time.sleep(1)

# %%
# get board info 
elem = browser.find_element_by_tag_name("body")
links = elem.find_elements_by_xpath('//a[@data-element-type = "36"]')
for l in links:
    bucket_pins.add(l.get_attribute('href'))

# %%
no_of_pagedowns = 100
#load more pages
while no_of_pagedowns:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.2)
    no_of_pagedowns-=1

# %%
links = elem.find_elements_by_xpath('//a[@data-element-type = "36"]')

# %%
for l in links:
    bucket_pins.add(l.get_attribute('href'))

# %%
len(bucket_pins)
# Out:
# 537

# %% [markdown]
# parse boards info

# %%
boards = list(bucket_pins)

# %%
boards_lis = parse_boards(boards)

# %%
boards_lis
# Out:
# [u'/stephahensley/face/',
#  u'/aleyunderwood/face-%2B-hair/',
#  u'/kaleroxie/face/',
#  u'/moriahberryhill/face/',
#  u'/lizajginnings/face/',
#  u'/rushintospace/face/',
#  u'/artpropelled/about-face/',
#  u'/YouYingying/face/',
#  u'/jadestenhouse/face/',
#  u'/lachicadeoro/face/',
#  u'/Katie0verbeek/face/',
#  u'/carlykee/face/',
#  u'/moiminnie/face/',
#  u'/nikkirowe72/face/',
#  u'/mingmingtt/face/',
#  u'/olivia14k/face/',
#  u'/StarryCrazed/face/',
#  u'/sevensisterspdx/face/',
#  u'/felizardx/face/',
#  u'/pplaceman/face/',
#  u'/pzavala9/face/',
#  u'/anorthcook/face/',
#  u'/liaburkeglaser/face/',
#  u'/luv2bead34/face/',
#  u'/bls1628/face/',
#  u'/laurenbourquin/face/',
#  u'/JessCochraneArt/face/',
#  u'/Anastasx/face/',
#  u'/stfne_marie/face/',
#  u'/underJupkaMy/face/',
#  u'/chelsea4real/face/',
#  u'/elisxbxth_s/face/',
#  u'/cornwellcamilla/face/',
#  u'/nicholsondesign/face/',
#  u'/jainabrooke/face/',
#  u'/Shop34North/face/',
#  u'/ashilepriester/face/',
#  u'/adrienneberlin/face/',
#  u'/carina_s/face/',
#  u'/sharvey/face-paint/',
#  u'/shall06/face/',
#  u'/prohibition/face/',
#  u'/kenasyn/face/',
#  u'/drawing101/face/',
#  u'/lucyapple/face/',
#  u'/davinyaclark/face/',
#  u'/hellobardeaux/face/',
#  u'/melissacstover/face/',
#  u'/itsdarbykayaye/face/',
#  u'/brennay/face/',
#  u'/livkirby/face/',
#  u'/matildawoulfe/face/',
#  u'/birchbox/face/',
#  u'/daniellemarii/face/',
#  u'/mccallyr/face/',
#  u'/lelooleloup/face/',
#  u'/pieraluisa/face-time/',
#  u'/leahhofff/face/',
#  u'/foldinvites/face/',
#  u'/RefusalToComply/face/',
#  u'/meagandomangue/face/',
#  u'/anukabanuka/face/',
#  u'/romilavin/face/',
#  u'/deniseheartsxo/face/',
#  u'/broek1/face/',
#  u'/schmami/face/',
#  u'/guywithcamera/face/',
#  u'/miemonster/face/',
#  u'/mallybeauty/doll-face/',
#  u'/xandragirl/face/',
#  u'/Keatabigail/~face~/',
#  u'/bellabumble/face/',
#  u'/joomklangsin/face/',
#  u'/aklupp/face/',
#  u'/ldbabrooklyn/face-etc/',
#  u'/senicho2/face/',
#  u'/72paristexas/face/',
#  u'/meghan_olesen1/face/',
#  u'/alysonsredding/face/',
#  u'/thelaurenedit/face/',
#  u'/fefeee/face/',
#  u'/thoralora/face/',
#  u'/erobynjones/face/',
#  u'/natashakstokes/face/',
#  u'/jessicavittone/face/',
#  u'/halseyfeels/face/',
#  u'/xAliceRogers/face/',
#  u'/lorangebrown/face/',
#  u'/roxieferguson1/face/',
#  u'/isabellamtwo/face/',
#  u'/littlelard1421/face/',
#  u'/mrscwb/face/',
#  u'/haaalle/face/',
#  u'/applepaperplane/face/',
#  u'/laurencesimonci/face/',
#  u'/laurenbalingit/face/',
#  u'/erinkaetrimble/face/',
#  u'/raelynnfinch/face/',
#  u'/sinequanum/face/',
#  u'/11je12je/beautiful-face/',
#  u'/hilary_',
#  u'/daliabarja/face/',
#  u'/ionadelmar/face/',
#  u'/mselizabethcook/face/',
#  u'/marenelyce/face/',
#  u'/tinymountains/face/',
#  u'/alexxissabo/face/',
#  u'/littlemianmian/face/',
#  u'/jackbaradad/face/',
#  u'/mwwwwwwwwwm/face/',
#  u'/vajaranant/face/',
#  u'/MrsDevis/face/',
#  u'/autumnuhh/face/',
#  u'/thehambledon/face-it/',
#  u'/kickpleat/about-face/',
#  u'/miGUELHERRANZok/face/',
#  u'/saiserpas/face/',
#  u'/misslarkin/face/',
#  u'/lisasteindesign/face/',
#  u'/janelleeriksen/face/',
#  u'/flowerbydrew/face/',
#  u'/j2thee2thenny/face/',
#  u'/mfrogers/face/',
#  u'/valkyriedb/face/',
#  u'/alphachi/face/',
#  u'/kb2244/face/',
#  u'/clareplueckhahn/face/',
#  u'/sphphllps17/face/',
#  u'/sokcs85/face/',
#  u'/Klaravikel/face/',
#  u'/tiffanywhosis/face/',
#  u'/asiarose/face/',
#  u'/angieglaze2510/face/',
#  u'/manuelmir/face/',
#  u'/TessaGiberson/face/',
#  u'/clairebusby/face/',
#  u'/georgiafelop/face/',
#  u'/marcialoureiro/face/',
#  u'/cathleenbishop/face/',
#  u'/zeronis/face/',
#  u'/alyssadelanny/face/',
#  u'/jlinneaw/that-face/',
#  u'/soyahplant/face/',
#  u'/bond/face/',
#  u'/ffionwright/face/',
#  u'/cubsofwar/face/',
#  u'/kaitparkinson/face/',
#  u'/kat/face/',
#  u'/katehutson/face/',
#  u'/sarahallin/face/',
#  u'/lalar/face/',
#  u'/martaennes/%2B%2B-face-%2B%2B/',
#  u'/HelloVogue/face/',
#  u'/emsteps/face/',
#  u'/sarahhmrob/face/',
#  u'/xpuffystaticx/face/',
#  u'/royuh/face/',
#  u'/nicolefarrugia/face/',
#  u'/wardwalton/face/',
#  u'/savetheants/face/',
#  u'/Dv8nt1/face/',
#  u'/einateliash/face/',
#  u'/ahan90/face/',
#  u'/dgroom/face/',
#  u'/mandyshay/face/',
#  u'/g00fyness/face/',
#  u'/fixiwawa/face/',
#  u'/helsingfors67/face/',
#  u'/shelbydrews/face/',
#  u'/LydiaPhillips93/face/',
#  u'/alistairjacklyn/your-face/',
#  u'/paolocasti/face/',
#  u'/jrguerhard/face/',
#  u'/stephanyonabike/face/',
#  u'/thestylingline/face/',
#  u'/silogrimm/face/',
#  u'/gaylynlang/face/',
#  u'/theCV/face/',
#  u'/adriavaidila/face/',
#  u'/innafranco/face/',
#  u'/sandragerber/face/',
#  u'/johannasor/face/',
#  u'/markk/face/',
#  u'/christinejonas/face/',
#  u'/gwenhwyfar/face/',
#  u'/lmneal87/face/',
#  u'/littlestg/face/',
#  u'/99gg/face/',
#  u'/utopianmel/face/',
#  u'/sarazancotti/face/',
#  u'/heysarahfun/face/',
#  u'/afifaf/face/',
#  u'/laurelhardy2/face/',
#  u'/ashleylydia/face/',
#  u'/jvanifatieva/face/',
#  u'/junior/face/',
#  u'/ginnybranch/faces/',
#  u'/annaclaudia/face/',
#  u'/chanelsmom/face/',
#  u'/cutiekat0916/face/',
#  u'/atelierbrenda/face/',
#  u'/dazi88/face/',
#  u'/bellaabriellee/face/',
#  u'/hairlady74/face/',
#  u'/estherjlnoben/face/',
#  u'/idkmybffjes/face/',
#  u'/vicentete/face/',
#  u'/aimee_payne/face/',
#  u'/angelawhite/face/',
#  u'/SteevieKing2/face/',
#  u'/jeremyepstein/face/',
#  u'/elizabethmburns/face/',
#  u'/hannahnachemson/face/',
#  u'/13rm/face/',
#  u'/pizzapartay/face/',
#  u'/allheredeer/face/',
#  u'/sheandvie/face/',
#  u'/skingun/face/',
#  u'/daniellebilen/face/',
#  u'/indiamelu/face/',
#  u'/chisakofukuyama/face/',
#  u'/msjordankay/face/',
#  u'/drbrandt/face/',
#  u'/afs61/face/',
#  u'/angiedrhyme/face/',
#  u'/lexiedixon/face/',
#  u'/bettydorotik/face/',
#  u'/heatherlindam/face/',
#  u'/kornianne/face/',
#  u'/nelliestman/face/',
#  u'/aubreyjanae/face/',
#  u'/kazuohattori/face/',
#  u'/keyzmo/face/',
#  u'/beeebeeeb/face/',
#  u'/patpongteekayu/face/',
#  u'/Dongsookang/face/',
#  u'/geoffang/face/',
#  u'/bronzehearts/face-/',
#  u'/emanvel/face/',
#  u'/blackswanbrand/face/',
#  u'/virtuelsie/face/',
#  u'/margaret_c/face/',
#  u'/emmalionm/face/',
#  u'/nowerys81/face/',
#  u'/IdkBeYourself/face/',
#  u'/sylphswanky/face/',
#  u'/faeraee/face/',
#  u'/shantellesjub/face/',
#  u'/achukk/hair-face/',
#  u'/ycccos/face/',
#  u'/xliakimx/face-3/',
#  u'/Morannc/face/',
#  u'/noaec/face/',
#  u'/shopjuliamarie/face/',
#  u'/mollybridgwood/face/',
#  u'/algirdoart/face/',
#  u'/jessicalinton/face/',
#  u'/Tschabe/face/',
#  u'/nikki_lou_/face/',
#  u'/Formhelden/face/',
#  u'/uxxx/facenail/',
#  u'/likethejuice/face/',
#  u'/stormyday/face/',
#  u'/matthewdkenyon/face/',
#  u'/happysolez/face-and-beauty-products/',
#  u'/bubbybloom/face/',
#  u'/ashprincesa/face/',
#  u'/cathled/face/',
#  u'/empresswood/face/',
#  u'/tonirdguez/face-drawings/',
#  u'/andlyyli/face/',
#  u'/scaranta/face/',
#  u'/mdrcode/face/',
#  u'/olgabv1/face/',
#  u'/haleighvivion/face/',
#  u'/EmilyRosehey/face/',
#  u'/jaymeditto/doll-face/',
#  u'/liyabrook/face/',
#  u'/cynthiamittweg/face/',
#  u'/siouxxsiee/face/',
#  u'/rachelley/face/',
#  u'/foxtwins/face/',
#  u'/anniepetela/face/',
#  u'/adnanalabdali/face/',
#  u'/paulahanson/face/',
#  u'/thecatalog/face/',
#  u'/livvdiodato/face/',
#  u'/thesoundoholic/face/',
#  u'/marimac8/face/',
#  u'/toanquyen/face/',
#  u'/oohasparkley/face/',
#  u'/jordynlorenz/face/',
#  u'/nifossi/face/',
#  u'/andreapack1/face/',
#  u'/AlisonOdowski/face/',
#  u'/erincolton/face/',
#  u'/klwdd/face/',
#  u'/123beemarie/face/',
#  u'/bohemiandiesel/face/',
#  u'/amber102188/face/',
#  u'/morganb15/face/',
#  u'/jmcbride139/face/',
#  u'/CosmeticsKIKO/face/',
#  u'/Amarizeo/face/',
#  u'/crisslinn/face~/',
#  u'/emsmithson/face/',
#  u'/a1b1c1d1/face/',
#  u'/bueller/face/',
#  u'/oohlalatea/face/',
#  u'/jimenezcaballer/face/',
#  u'/maddiebrenton/face/',
#  u'/georgiagrdn/face/',
#  u'/monomania/face/',
#  u'/nataliabertova3/face/',
#  u'/audra6901/face/',
#  u'/trustic/face/',
#  u'/cicelysweed/face/',
#  u'/allibyrum/face/',
#  u'/rachelltz/face/',
#  u'/redposy/face/',
#  u'/280566th/face/',
#  u'/kalistalandry/face/',
#  u'/hopeedmondzon/face/',
#  u'/nylons/face/',
#  u'/mmwrigle/face/',
#  u'/susannahope/face/',
#  u'/coolcalmquiet/bldgface/',
#  u'/AInteriorDsign/face/',
#  u'/pkam/face/',
#  u'/villageliz/face/',
#  u'/k3llykaufman/face/',
#  u'/fionabooth/face/',
#  u'/ling000/face/',
#  u'/katiemccord/face/',
#  u'/viapetty/face/',
#  u'/wrinklesintime/face/',
#  u'/milliekatherine/face/',
#  u'/pindudette/face/',
#  u'/apcavalari/face/',
#  u'/gieanu/face/',
#  u'/richardmsteed/face/',
#  u'/katieashby/face/',
#  u'/lomakingg/f%2Bface/',
#  u'/amyprior/face/',
#  u'/sarahatsavage/face/',
#  u'/zuango/face/',
#  u'/aqiskincare/face/',
#  u'/TOYORI/face/',
#  u'/lanishipman/face/',
#  u'/marykelle/face/',
#  u'/Citygoblin/face/',
#  u'/whomakeit/face/',
#  u'/chelseavdbi/face/',
#  u'/damiriamachado/face/',
#  u'/erinmariejude/face/',
#  u'/twigsandhoney/face/',
#  u'/vivachaim/face/',
#  u'/threehours/face/',
#  u'/dpaz77/face/',
#  u'/ahimgina/face/',
#  u'/AdeleFox01/face/',
#  u'/studiogabe/faces/',
#  u'/franonumah/face/',
#  u'/STisdelStudio/face/',
#  u'/mermag/face/',
#  u'/inmysundaybest/face-paint/',
#  u'/SOCRATICJUNKIE/face/',
#  u'/foatdesign/face/',
#  u'/hellofigandsalt/face-%2B-form/',
#  u'/becksbrown/face/',
#  u'/lauramcdew/face/',
#  u'/punktd/face/',
#  u'/heatherowens/face/',
#  u'/robinhilleary/face/',
#  u'/teiraila/face/',
#  u'/veronique15/face/',
#  u'/elllielauren/face/',
#  u'/laughingstars/face/',
#  u'/jonibjohnson/face/',
#  u'/ashhulley/face/',
#  u'/moon16/face/',
#  u'/csrn/face/',
#  u'/BobHefferan/face/',
#  u'/nancyisabelle/face/',
#  u'/catermillar/face/',
#  u'/mae_zaragoza/face/',
#  u'/c57234/face/',
#  u'/fotiadi/face/',
#  u'/delirousinparis/face/',
#  u'/jhijo0948/face/',
#  u'/valwieser/face/',
#  u'/caitkitt/face/',
#  u'/nataliebnelson/face/',
#  u'/romaisvaje/face/',
#  u'/mastersphotoqc/face/',
#  u'/ismay/face/',
#  u'/onoMARApoeia/face/',
#  u'/neusafujimoto/face/',
#  u'/helios3d/face/',
#  u'/cloud0227/face/',
#  u'/sophiedetermann/face/',
#  u'/sarahlpugliese/face/',
#  u'/freepeople/face/',
#  u'/DickHarends/face/',
#  u'/heraaban/face/',
#  u'/ilricettario/face/',
#  u'/dolorousjewelry/face/',
#  u'/somethingpretty/face/',
#  u'/valvon/face/',
#  u'/summerdeforest/face/',
#  u'/magnobottrel/face/',
#  u'/oldflavour/face/',
#  u'/nashtrevelyan/face/',
#  u'/jussdrinktea/face/',
#  u'/ariscottiepup/face/',
#  u'/AliciaNeuman/face/',
#  u'/holstkarall/face/',
#  u'/cesaramon/face/',
#  u'/annanaphtali/face/',
#  u'/yassi80/face-painting/',
#  u'/elizabethdj1989/face/',
#  u'/missmonahan88/face/',
#  u'/heidekl/face/',
#  u'/laylavattel/face/',
#  u'/melody_wear/face/',
#  u'/snjoka/face/',
#  u'/bholzke/face/',
#  u'/shazach27/face/',
#  u'/inolai/face/',
#  u'/sam_dawn/face/',
#  u'/kaityhoff/face/',
#  u'/b4technicolor/face/',
#  u'/bethawho/face/',
#  u'/byrdiebeautyau/face/',
#  u'/fergusonstace/face/',
#  u'/ivy_thompson/face/',
#  u'/kanArtomo/face/',
#  u'/myrodoodles/face/',
#  u'/lillesmy/face/',
#  u'/gronandwhite/face/',
#  u'/jjulishka/face/',
#  u'/frannyg/face/',
#  u'/held76/face-painting/',
#  u'/eujinrhee/about-face/',
#  u'/designboom/faceades/',
#  u'/Peachhh/face/',
#  u'/taykwas/face/',
#  u'/fumikamigama/face/',
#  u'/Wellapptdesk/face-it/',
#  u'/michewats/face/',
#  u'/allybeeeee/face/',
#  u'/tkclovesrwc/face/',
#  u'/nannabug/face/',
#  u'/rrrenly/face/',
#  u'/colorymck/face/',
#  u'/oliviayichen/face/',
#  u'/laudydaudy/face/',
#  u'/hopeless/face/',
#  u'/ayonnaise/face%2B/',
#  u'/20somethingplus/face/',
#  u'/spacekittens/face/',
#  u'/stellafinley/face/',
#  u'/wanchong/face/',
#  u'/pinkliza/face/',
#  u'/diamondkay90/face/',
#  u'/beebarkandmoss/face/',
#  u'/getyourbestbody/face/',
#  u'/realovespink/face/',
#  u'/Five12Studio/face/',
#  u'/t3ssanoble/face/',
#  u'/tonnadawn/face/',
#  u'/robynical/face/',
#  u'/lidiaghazaryan/face~/',
#  u'/jillcamos/face/',
#  u'/marcsublet/faces/',
#  u'/kathleenadantas/face/',
#  u'/bohobrewco/face/',
#  u'/adnufgablisey/face/',
#  u'/LaRecouze/face-%C3%A0-face-2/',
#  u'/peachcheek/face/',
#  u'/KlaraMP/face/',
#  u'/candidlycreole/face/',
#  u'/staceyconlan/face/',
#  u'/ahsheegrek/face/',
#  u'/hello_bombshell/face/',
#  u'/oliviasimons/face/',
#  u'/kseniakil1995/face/',
#  u'/frannieshell/face/',
#  u'/lbartkute/face/',
#  u'/katexarmstrong/face/',
#  u'/courtneyhyder/face/',
#  u'/alishacassandra/face/',
#  u'/galleryjeon/face/',
#  u'/breannecsolomon/face/',
#  u'/pohlymnie/face/',
#  u'/odeforest/face/',
#  u'/roladd/face/',
#  u'/joneshairdesign/face/',
#  u'/hcrossed/face/',
#  u'/etlerves/face/',
#  u'/nadc/face/',
#  u'/zillaa/face/',
#  u'/LouLouBARE/face/',
#  u'/camillawhitman/face/',
#  u'/milknhoneyblog/face/',
#  u'/adrithoeny/face/',
#  u'/savannahnall/face/',
#  u'/leightonrenee/face/',
#  u'/alexisjwho/face/',
#  u'/savannahfm/face/',
#  u'/minjiii/face/',
#  u'/pesus/face/',
#  u'/bambibonbon/face/',
#  u'/youyunart/face/',
#  u'/buxxxyyysi/face/',
#  u'/kajadons/face/',
#  u'/anantinomy/face/',
#  u'/thestripeny/about-face/',
#  u'/kaidaria/face/',
#  u'/jpete/face/',
#  u'/marshaedrea/face/',
#  u'/kira4kasper/face/',
#  u'/laurenenglish/face/',
#  u'/intransfer/face/',
#  u'/darlamaxine/face/',
#  u'/hellokristiee/face/',
#  u'/denivev/face/',
#  u'/pnali/face/',
#  u'/sungchaey/face/',
#  u'/islaay/face/',
#  u'/emiloumitchell/face/',
#  u'/ksavrani/face/',
#  u'/nicoleloree/face/',
#  u'/melissajsoule/face/']

# %%
with open('../data/boards.pkl',"w") as f:
    pickle.dump(boards_lis,f)
